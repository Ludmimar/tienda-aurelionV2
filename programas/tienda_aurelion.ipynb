# %% [markdown]
# # ⚔️ TIENDA AURELION - SISTEMA DE GESTIÓN DE INVENTARIO
#
# **Sprint 2 - Introducción a la Inteligencia Artificial - IBM**
#
# ---
#
# ## 📋 Índice
# 1. [Tema, Problema y Solución](#tema)
# 2. [Fuente de Datos](#fuente)
# 3. [Estructura de Datos](#estructura)
# 4. [Desarrollo del Programa](#desarrollo)
# 5. [Demostración Interactiva](#demo)
# 6. [Análisis y Estadísticas](#analisis)
# 7. [Hallazgos y Conclusiones](#conclusiones)

# %% [markdown]
# ---
#
# ## 1. 🎯 Tema, Problema y Solución <a id='tema'></a>
#
# ### Tema
# **Sistema de Gestión de Inventario para Tienda de Fantasía Medieval**
#
# La Tienda Aurelion es un comercio especializado en artículos mágicos y de aventura.
#
# ### El Problema
# - ❌ **Gestión manual ineficiente** - Registro en papel causa errores
# - ❌ **Falta de visibilidad** - No hay forma rápida de consultar productos
# - ❌ **Control de stock deficiente** - No se detectan productos con bajo inventario
# - ❌ **Sin análisis de datos** - No hay estadísticas ni reportes
#
# ### La Solución
# ✅ **Sistema Interactivo en Python** que permite:
# - Consultar productos por múltiples criterios
# - Generar estadísticas automáticas
# - Alertas de productos con stock bajo
# - Gestión completa del inventario (agregar/actualizar)

# %% [markdown]
# ---
#
# ## 2. 📊 Fuente de Datos <a id='fuente'></a>
#
# ### Origen
# Datos históricos de la Tienda Aurelion, recopilados durante **2 años de operación**.
#
# ### Método de Recolección
# - Registro de productos ingresados al inventario
# - Información de proveedores
# - Clasificación manual por categorías
# - Actualización continua de precios y stock
#
# ### Almacenamiento
# **Formato CSV** (Comma-Separated Values)
# - ✅ Fácil lectura y escritura
# - ✅ Compatible con Excel, Python, bases de datos
# - ✅ Portable y respaldo sencillo
# - ✅ Bajo consumo de recursos

# %% [markdown]
# ---
#
# ## 3. 🗂️ Estructura de Datos <a id='estructura'></a>
#
# ### Campos del Dataset
#
# | Campo | Tipo | Tipo Python | Escala | Ejemplo |
# |-------|------|-------------|--------|---------|
# | **id** | Numérico entero | `int` | 1-20 | 1 |
# | **nombre** | Texto | `str` | 10-30 chars | "Espada Celestial" |
# | **categoria** | Categórico | `str` | 10 únicas | "Armas" |
# | **precio** | Numérico entero | `int` | 25-5000 | 1500 |
# | **stock** | Numérico entero | `int` | 3-500 | 25 |
# | **descripcion** | Texto | `str` | 20-50 chars | "Espada forjada..." |
# | **proveedor** | Categórico | `str` | 9 únicos | "Forja Celestial" |
#
# ### Clasificación de Variables
#
# **Variables Cuantitativas:**
# - `precio` - Continua (discreta en práctica)
# - `stock` - Discreta
# - `id` - Discreta
#
# **Variables Cualitativas:**
# - `nombre`, `categoria`, `descripcion`, `proveedor` - Nominales

# %%
# Importar librerías necesarias
import csv
from typing import List, Dict, Optional

# Configuración
ARCHIVO_CSV = "../datos/tienda_aurelion.csv"
UMBRAL_STOCK_BAJO = 20

print("✅ Librerías importadas correctamente")
print(f"📁 Archivo de datos: {ARCHIVO_CSV}")
print(f"⚠️  Umbral de stock bajo: {UMBRAL_STOCK_BAJO} unidades")

# %%
def cargar_datos() -> List[Dict]:
    """Carga los datos del archivo CSV."""
    productos = []
    try:
        with open(ARCHIVO_CSV, 'r', encoding='utf-8') as archivo:
            lector = csv.DictReader(archivo)
            for fila in lector:
                try:
                    fila['id'] = int(fila['id'])
                    fila['precio'] = int(fila['precio'])
                    fila['stock'] = int(fila['stock'])
                    productos.append(fila)
                except (ValueError, KeyError) as e:
                    print(f"⚠️  Error en fila: {e}")
                    continue
        print(f"✅ Se cargaron {len(productos)} productos correctamente.")
        return productos
    except FileNotFoundError:
        print(f"❌ No se encontró el archivo")
        return []

# Cargar los datos
productos = cargar_datos()

# %%
# Mostrar los primeros 3 productos
print("📦 PRIMEROS 3 PRODUCTOS:\n")
for i, p in enumerate(productos[:3], 1):
    print(f"▶️  Producto {i}:")
    for campo, valor in p.items():
        print(f"   {campo:12s}: {valor}")
    print("-" * 70)

# %% [markdown]
# ---
#
# ## 4. 💻 Desarrollo del Programa <a id='desarrollo'></a>
#
# ### Funciones Principales del Sistema

# %%
def mostrar_producto(producto: Dict):
    """Muestra información formateada de un producto."""
    print(f"{'─' * 70}")
    print(f"  🆔 ID:          {producto['id']}")
    print(f"  📦 Nombre:      {producto['nombre']}")
    print(f"  🏷️  Categoría:   {producto['categoria']}")
    print(f"  💰 Precio:      {producto['precio']} monedas")
    print(f"  📊 Stock:       {producto['stock']} unidades", end="")
    if producto['stock'] <= UMBRAL_STOCK_BAJO:
        print(" ⚠️  ¡STOCK BAJO!")
    else:
        print()
    print(f"  📝 Descripción: {producto['descripcion']}")
    print(f"  🏪 Proveedor:   {producto['proveedor']}")
    print(f"{'─' * 70}")

# %%
def buscar_por_categoria(productos: List[Dict], categoria: str):
    """Busca productos de una categoría específica."""
    print(f"\n🏷️  BÚSQUEDA: '{categoria}'\n")
    resultados = [p for p in productos if p['categoria'].lower() == categoria.lower()]
    if resultados:
        print(f"✅ Encontrados: {len(resultados)} producto(s)\n")
        for p in resultados:
            mostrar_producto(p)
    else:
        print(f"❌ No se encontraron productos")

# %%
def buscar_por_rango_precios(productos: List[Dict], precio_min: int, precio_max: int):
    """Busca productos en un rango de precios."""
    print(f"\n💰 RANGO: {precio_min} - {precio_max} monedas\n")
    resultados = [p for p in productos if precio_min <= p['precio'] <= precio_max]
    if resultados:
        print(f"✅ Encontrados: {len(resultados)} producto(s)\n")
        for p in resultados:
            mostrar_producto(p)
    else:
        print(f"❌ No se encontraron productos")

# %%
def productos_bajo_stock(productos: List[Dict]):
    """Muestra productos con stock bajo."""
    print(f"\n⚠️  PRODUCTOS CON STOCK BAJO (≤{UMBRAL_STOCK_BAJO})\n")
    resultados = sorted([p for p in productos if p['stock'] <= UMBRAL_STOCK_BAJO], 
                       key=lambda x: x['stock'])
    if resultados:
        print(f"⚠️  Encontrados: {len(resultados)} producto(s) CRÍTICOS\n")
        for p in resultados:
            mostrar_producto(p)
        print(f"\n💡 Sugerencia: Contactar proveedores para reabastecer")
    else:
        print("✅ Todos los productos tienen stock adecuado")

# %%
def estadisticas_inventario(productos: List[Dict]):
    """Genera estadísticas del inventario."""
    print("\n📊 ESTADÍSTICAS DEL INVENTARIO\n")
    
    total = len(productos)
    stock_total = sum(p['stock'] for p in productos)
    valor_total = sum(p['precio'] * p['stock'] for p in productos)
    categorias = len(set(p['categoria'] for p in productos))
    proveedores = len(set(p['proveedor'] for p in productos))
    
    mas_caro = max(productos, key=lambda x: x['precio'])
    mas_barato = min(productos, key=lambda x: x['precio'])
    precio_prom = sum(p['precio'] for p in productos) / total
    stock_prom = stock_total / total
    
    print(f"{'═' * 70}")
    print("  ESTADÍSTICAS GENERALES")
    print(f"{'═' * 70}")
    print(f"  📦 Total productos:        {total}")
    print(f"  🏷️  Categorías únicas:      {categorias}")
    print(f"  🏪 Proveedores únicos:     {proveedores}")
    print(f"  📊 Stock total:            {stock_total} unidades")
    print(f"  💰 Valor total inventario: {valor_total:,} monedas")
    print(f"  💵 Precio promedio:        {precio_prom:.2f} monedas")
    print(f"  📈 Stock promedio:         {stock_prom:.2f} unidades")
    print(f"{'═' * 70}\n")
    
    print("  💎 Más caro:", mas_caro['nombre'], f"({mas_caro['precio']} monedas)")
    print("  🎯 Más económico:", mas_barato['nombre'], f"({mas_barato['precio']} monedas)")

# %% [markdown]
# ---
#
# ## 5. 🎮 Demostración Interactiva <a id='demo'></a>
#
# Ahora vamos a probar todas las funcionalidades del sistema.

# %%
# Demo 1: Mostrar primeros 5 productos
print("📋 PRIMEROS 5 PRODUCTOS:\n")
for i, p in enumerate(productos[:5], 1):
    print(f"\n▶️  Producto #{i}")
    mostrar_producto(p)

# %%
# Demo 2: Buscar productos de categoría "Armas"
buscar_por_categoria(productos, "Armas")

# %% [markdown]
# ---
#
# ## 👨‍💻 Información del Autor
#
# **Autor:** Martos Ludmila
# **DNI:** 34811650
# **Institución:** IBM
# **Sprint:** 2 - Introducción a la Inteligencia Artificial
# **Año:** 2025
#
# ---
#
# **© 2025 Martos Ludmila - Tienda Aurelion**

# %%
# Demo 3: Buscar productos de categoría "Pociones"
buscar_por_categoria(productos, "Pociones")

# %%
# Demo 4: Buscar productos en rango 500-1500 monedas
buscar_por_rango_precios(productos, 500, 1500)

# %%
# Demo 5: Productos con stock bajo (ALERTA)
productos_bajo_stock(productos)

# %% [markdown]
# ---
#
# ## 6. 📈 Análisis y Estadísticas <a id='analisis'></a>

# %%
# Estadísticas generales
estadisticas_inventario(productos)

# %%
# Análisis por categoría
print("\n📊 ANÁLISIS POR CATEGORÍA\n" + "=" * 80)
categorias = sorted(set(p['categoria'] for p in productos))
for cat in categorias:
    prods = [p for p in productos if p['categoria'] == cat]
    stock = sum(p['stock'] for p in prods)
    valor = sum(p['precio'] * p['stock'] for p in prods)
    print(f"\n🏷️  {cat}")
    print(f"   • Productos: {len(prods)}")
    print(f"   • Stock total: {stock} unidades")
    print(f"   • Valor total: {valor:,} monedas")

# %%
# Top 5 productos por valor en inventario
print("\n💎 TOP 5 POR VALOR EN INVENTARIO\n" + "=" * 80)
productos_valor = [(p, p['precio'] * p['stock']) for p in productos]
productos_valor.sort(key=lambda x: x[1], reverse=True)
for i, (p, valor) in enumerate(productos_valor[:5], 1):
    print(f"\n🏆 #{i} - {p['nombre']}")
    print(f"   Precio: {p['precio']} | Stock: {p['stock']} | Valor: {valor:,} monedas")

# %% [markdown]
# ---
#
# ## 7. 📋 Hallazgos y Conclusiones <a id='conclusiones'></a>
#
# ### Hallazgos Principales
#
# #### 1. Estado del Inventario
# - ✅ **20 productos** distribuidos en **10 categorías**
# - ⚠️ **3 productos** con stock crítico
# - ✅ **85%** de productos con stock saludable
#
# #### 2. Análisis Financiero
# - 💰 Valor total: **85,075 monedas de oro**
# - 📊 Rango de precios: **25 - 5,000 monedas** (200x diferencia)
# - 💵 Precio promedio: **932 monedas**
#
# #### 3. Diversificación
# - ✅ **9 proveedores** diferentes (buena diversificación)
# - ✅ Catálogo balanceado entre económicos y premium
# - ✅ Múltiples categorías
#
# #### 4. Productos Críticos (Requieren Reabastecimiento)
# - ⚠️ **Gema de Resurrección**: 3 unidades (alto valor, bajo stock)
# - ⚠️ **Grimorio Antiguo**: 8 unidades
# - ⚠️ **Capa de Invisibilidad**: 10 unidades
#
# ### Recomendaciones
#
# **Corto Plazo:**
# - ⚠️ Reabastecer 3 productos críticos inmediatamente
# - 📊 Implementar alertas automáticas
# - 💾 Backup semanal del inventario
#
# **Mediano Plazo:**
# - 📈 Análisis de tendencias de ventas
# - 🤖 Predicción de demanda con ML
# - 📊 Dashboard en Power BI
#
# **Largo Plazo:**
# - 🌐 Migrar a SQL si crece >100 productos
# - 📱 App móvil para gestión
# - 🔗 Integración con sistema de ventas

# %% [markdown]
# ### Sugerencias de Copilot
#
# Durante el desarrollo se evaluaron **20 sugerencias de IA**:
#
# **✅ Aceptadas (10):**
# 1. `csv.DictReader` - Mejor legibilidad
# 2. Conversión explícita de tipos
# 3. Validación centralizada
# 4. F-strings para formateo
# 5. Context managers (`with`)
# 6. Type hints
# 7. Separadores Unicode
# 8. Emojis temáticos
# 9. List comprehensions
# 10. `sorted()` con key
#
# **❌ Descartadas (10):**
# 1. SQLite - Innecesario para 20 productos
# 2. GUI tkinter - Fuera del alcance
# 3. Pandas - Dependencia externa innecesaria
# 4. Autenticación - No requerido
# 5. Logging - Print es suficiente
# 6. Regex - Overkill
# 7. POO con clases - Estructura simple mejor
# 8. Virtualenv - Sin dependencias
# 9. Tests unitarios - Demo educativa
# 10. API REST - Fuera del alcance
#
# **Criterio:** Simplicidad, portabilidad y requisitos del proyecto.

# %% [markdown]
# ---
#
# ## 📚 Información del Proyecto
#
# **Proyecto:** Tienda Aurelion - Sistema de Gestión de Inventario
# **Sprint:** 1 - Introducción a la Inteligencia Artificial
# **Institución:** IBM
# **Año:** 2025
#
# ### Archivos del Proyecto
# - `tienda_aurelion.csv` - Base de datos
# - `tienda_aurelion.ipynb` - Este notebook (Jupyter)
# - `tienda_aurelion.py` - Versión script Python
# - `README.md` - Documentación completa
# - `PSEUDOCODIGO_Y_DIAGRAMAS.md` - Algoritmos
# - `SUGERENCIAS_COPILOT.md` - Análisis de IA
# - `GUIA_POWER_BI.md` - Dashboard
# - `GUIA_PRESENTACION.md` - Presentación oral
#
# ### Tecnologías
# - Python 3.6+
# - Jupyter Notebook
# - Librería CSV (estándar)
# - Markdown
#
# ---
#
# **¡Proyecto completo y funcional! ⚔️✨**
